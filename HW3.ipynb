# %% [markdown]
# <a href="https://colab.research.google.com/github/RabiaYmrtc/RabiaYmrtc/blob/GlobalAIHubPythonCourse/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for prime_first in range(0,1000):     #to iterate between 10 to 20
  for prime_second in range(0,1000):
    if prime_first < 501:         #to determine the first factor
      print('prime_first')
      break
    else:
         prime_second>500            #to calculate the second factor
    print('prime_second')
    break
# Out:
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# prime_first
# ...
